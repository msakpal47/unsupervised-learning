# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
titanic= pd.read_csv('/kaggle/input/hierarchal-clustering-titanic-dataset/titanic_train.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic['Age'].dtype
# Out:
# dtype('float64')

# %%
titanic['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
titanic['Age'].mean()
# Out:
# 29.69911764705882

# %%
titanic['Age']=titanic['Age'].fillna(29.69911764705882)

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic['Cabin'].dtype
# Out:
# dtype('O')

# %%
titanic.drop('Cabin',inplace=True,axis=1)

# %%
titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
titanic['Sex'].dtype
# Out:
# dtype('O')

# %%
titanic['Male']=pd.get_dummies(titanic['Sex'],dtype=int,drop_first=True)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  Male
# 0      0         A/5 21171   7.2500        S     1
# 1      0          PC 17599  71.2833        C     0
# 2      0  STON/O2. 3101282   7.9250        S     0
# 3      0            113803  53.1000        S     0
# 4      0            373450   8.0500        S     1

# %%
titanic.drop('Sex', inplace=True, axis=1)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Embarked  Male
# 0         A/5 21171   7.2500        S     1
# 1          PC 17599  71.2833        C     0
# 2  STON/O2. 3101282   7.9250        S     0
# 3            113803  53.1000        S     0
# 4            373450   8.0500        S     1

# %%
titanic['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
titanic[['C','Q']]=pd.get_dummies(titanic['Embarked'],dtype=int,drop_first=True)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Embarked  Male  C  Q
# 0         A/5 21171   7.2500        S     1  0  1
# 1          PC 17599  71.2833        C     0  0  0
# 2  STON/O2. 3101282   7.9250        S     0  0  1
# 3            113803  53.1000        S     0  0  1
# 4            373450   8.0500        S     1  0  1

# %%
titanic.drop('Embarked', inplace=True,axis=1)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare  Male  C  Q
# 0         A/5 21171   7.2500     1  0  1
# 1          PC 17599  71.2833     0  0  0
# 2  STON/O2. 3101282   7.9250     0  0  1
# 3            113803  53.1000     0  0  1
# 4            373450   8.0500     1  0  1

# %%
titanic.drop(['PassengerId'],inplace=True,axis=1)

# %%
titanic.head()
# Out:
#    Survived  Pclass                                               Name   Age  \
# 0         0       3                            Braund, Mr. Owen Harris  22.0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2         1       3                             Heikkinen, Miss. Laina  26.0
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4         0       3                           Allen, Mr. William Henry  35.0
#
#    SibSp  Parch            Ticket     Fare  Male  C  Q
# 0      1      0         A/5 21171   7.2500     1  0  1
# 1      1      0          PC 17599  71.2833     0  0  0
# 2      0      0  STON/O2. 3101282   7.9250     0  0  1
# 3      1      0            113803  53.1000     0  0  1
# 4      0      0            373450   8.0500     1  0  1

# %%
titanic.drop(['Name'],inplace=True,axis=1)

# %%
titanic.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch            Ticket     Fare  Male  C  Q
# 0         0       3  22.0      1      0         A/5 21171   7.2500     1  0  1
# 1         1       1  38.0      1      0          PC 17599  71.2833     0  0  0
# 2         1       3  26.0      0      0  STON/O2. 3101282   7.9250     0  0  1
# 3         1       1  35.0      1      0            113803  53.1000     0  0  1
# 4         0       3  35.0      0      0            373450   8.0500     1  0  1

# %%
titanic.drop(['Ticket'],inplace=True,axis=1)

# %%
titanic.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Male  C  Q
# 0         0       3  22.0      1      0   7.2500     1  0  1
# 1         1       1  38.0      1      0  71.2833     0  0  0
# 2         1       3  26.0      0      0   7.9250     0  0  1
# 3         1       1  35.0      1      0  53.1000     0  0  1
# 4         0       3  35.0      0      0   8.0500     1  0  1

# %%
plt.figure(figsize=(8, 6))
sns.histplot(titanic['Age'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='Survived', data=titanic)
plt.title('Survival Count (0 = No, 1 = Yes)')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Pclass', y='Fare', data=titanic)
plt.title('Fare Distribution by Pclass')
plt.xlabel('Pclass')
plt.ylabel('Fare')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.barplot(x='Pclass', y='Survived', data=titanic, ci=None)
plt.title('Survival Rate by Pclass')
plt.xlabel('Pclass')
plt.ylabel('Survival Rate')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='Male', data=titanic)
plt.title('Count of Passengers by Gender (1 = Male)')
plt.xlabel('Male')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Age', y='Fare', data=titanic, hue='Survived')
plt.title('Age vs. Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x='Pclass', y='Age', data=titanic)
plt.title('Age Distribution by Pclass')
plt.xlabel('Pclass')
plt.ylabel('Age')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Survived', y='Age', data=titanic)
plt.title('Age Distribution by Survival')
plt.xlabel('Survived')
plt.ylabel('Age')
plt.show()

# %%
plt.figure(figsize=(10, 8))
corr = titanic.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
sns.pairplot(titanic[['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']], hue='Survived', diag_kind='kde')
plt.show()

# %%
# Assuming 'data' is your DataFrame containing the relevant columns

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import accuracy_score
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
# Selecting columns for clustering
X = titanic[['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Male', 'C', 'Q']]

# %%
# Scaling the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Applying hierarchical clustering
model = AgglomerativeClustering(n_clusters=2)  # 2 clusters for binary 'Survived'
clusters = model.fit_predict(X_scaled)

# %%
# Assessing accuracy by comparing predicted clusters with 'Survived'
predicted_survival = pd.Series(clusters)
accuracy = accuracy_score(titanic['Survived'], predicted_survival)

# %%
print(f"Accuracy of Hierarchical Clustering for predicting 'Survived': {accuracy:.2f}")
# Out:
# Accuracy of Hierarchical Clustering for predicting 'Survived': 0.60

# %%
# Plotting the dendrogram
plt.figure(figsize=(12, 8))
dendrogram(linkage(X_scaled, method='ward'))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Passenger Index')
plt.ylabel('Distance')
plt.show()
